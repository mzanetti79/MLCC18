# %% [markdown]
# # MLCC - Laboratory 3 - Dimensionality reduction and feature selection
#     In this laboratory we will address the problem of data analysis with a reference to a classification problem.
#     Follow the instructions below.

# %%
# Import the 
from lab3ImpFunction import *
import matplotlib.pyplot as plt

# %%
# main1
n = 100
dim = 30

Xtr, Ytr = MixGauss(means=[[1,-1],[1,1]],sigmas=[[0.7], [0.7]],n=n)
Ytr = 2*np.mod(Ytr, 2)-1

Xts, Yts = MixGauss(means=[[1,-1],[1,1]],sigmas=[[0.7], [0.7]],n=n)
Yts = 2*np.mod(Yts, 2)-1

plt.scatter(Xtr[:,0], Xtr[:,1], s=30, c=np.squeeze(Ytr), alpha=0.5)
plt.title('Plot data', fontsize=14, color='red')
plt.show()

# %%
sigma_noise = 0.01

Xtr_noise = sigma_noise * np.random.randn(2*n, dim-2)
Xts_noise = sigma_noise * np.random.randn(2*n, dim-2)

Xtr = np.concatenate((Xtr, Xtr_noise), axis=1)
Xts = np.concatenate((Xts, Xts_noise), axis=1)

V, d, X_proj = PCA(Xtr, 3)
print(X_proj.shape)

plt.scatter(X_proj[:,0], X_proj[:,1], s=30, c=np.squeeze(Ytr), alpha=0.5)

#print(np.mean(X_proj, axis=0))
plt.title('Second plot', fontsize=14, color='red')
plt.show()
# Out:
# (200, 3)

# %%
#PCA
#mean= Xtr.mean(axis=0)
#Xtr = Xtr - mean
#cov_mat = Xtr.T @ Xtr   
#X_proj, d, V = np.linalg.svd(cov_mat)

fig = pyplot.figure()
ax = Axes3D(fig)

x = X_proj[:,0].real
y = X_proj[:,1].real
z = X_proj[:,2].real

ax.scatter(x, y, z, c=np.squeeze(Ytr), marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
#V, d, X_proj = PCA(Xtr, 3);
print(np.sqrt(d[:10]))

#plt.scatter(list(range(D)), abs(X_proj[:,0]))
plt.scatter(range(dim), abs(d))

plt.show()
# Out:
# [ 18.04231894  10.38382542   0.18477747   0.18445196   0.17802895
#    0.17200072   0.16627179   0.16555072   0.15493746   0.1533165 ]

# %%
## Test on different sigma
n = 100
dim = 30

Xtr, Ytr = MixGauss(means=[[1,-1],[1,1]],sigmas=[[0.7], [0.7]],n=n)
Ytr = 2*np.mod(Ytr, 2)-1

Xts, Yts = MixGauss(means=[[1,-1],[1,1]],sigmas=[[0.7], [0.7]],n=n)
Yts = 2*np.mod(Yts, 2)-1

# %%
sigma_noise = 0.01;
Xtr_noise = sigma_noise * np.random.randn(2*n, dim-2);
Xts_noise = sigma_noise * np.random.randn(2*n, dim-2);

Xtr = np.concatenate((Xtr, Xtr_noise), axis=1)
Xts = np.concatenate((Xts, Xts_noise), axis=1)
# Normalize
m = np.mean(Xtr, axis=0)
s = np.std(Xtr, axis=0)

Xtr = (Xtr - m) / s
Xts = (Xts - m) / s

# %%
    
w, r, I = OMatchingPursuit(Xtr, Ytr, 5)
Ypred = np.sign(Xts.dot(w))

err = calcErr(Yts, Ypred);
plt.scatter(list(range(dim)), abs(w))
plt.title('Eigen values');
plt.show()

plt.scatter(Xts[:,1], Xts[:,2], 50, Yts, alpha=0.5)
plt.scatter(Xts[:,1], Xts[:,2], 20, Ypred, alpha=0.5)
plt.title('Two first dimensions and associated labels')
plt.show()

# %%
intIter = list(range(dim))
perc = 0.75
nrip = 20
it, Vm, Vs, Tm, Ts = holdoutCVOMP(Xtr, Ytr, perc, nrip, intIter)


plt.plot(intIter, Tm, 'r+');

plt.plot(intIter, Vm, 'b+');

plt.title('Cross validation results', fontsize=20, color='red'); 

plt.xlabel('Number of dimension', fontsize=12, color='red'); 
plt.ylabel('error', fontsize=12, color='red');

plt.show()
# Out:
# rip         Iter        valErr      trErr
# 0           1           0.060000    0.100000
# rip         Iter        valErr      trErr
# 0           2           0.113333    0.060000
# rip         Iter        valErr      trErr
# 0           3           0.126667    0.020000
# rip         Iter        valErr      trErr
# 0           4           0.106667    0.020000
# rip         Iter        valErr      trErr
# 0           5           0.120000    0.020000
# rip         Iter        valErr      trErr
# 0           6           0.120000    0.020000
# rip         Iter        valErr      trErr
# 0           7           0.120000    0.020000
# rip         Iter        valErr      trErr
# 0           8           0.120000    0.020000
# rip         Iter        valErr      trErr
# 0           9           0.120000    0.020000
# rip         Iter        valErr      trErr
# 0           10          0.113333    0.000000
# rip         Iter        valErr      trErr
# 0           11          0.120000    0.020000
# rip         Iter        valErr      trErr
# 0           12          0.133333    0.000000
# rip         Iter        valErr      trErr
# 0           13          0.133333    0.000000
# rip         Iter        valErr      trErr
# 0           14          0.133333    0.000000
# rip         Iter        valErr      trErr
# 0           15          0.153333    0.000000
# rip         Iter        valErr      trErr
# 0           16          0.133333    0.000000
# rip         Iter        valErr      trErr
# 0           17          0.173333    0.000000
# rip         Iter        valErr      trErr
# 0           18          0.213333    0.000000
# rip         Iter        valErr      trErr
# 0           19          0.206667    0.000000
# rip         Iter        valErr      trErr
# 0           20          0.200000    0.000000
# rip         Iter        valErr      trErr
# 0           21          0.200000    0.000000
# rip         Iter        valErr      trErr
# 0           22          0.200000    0.000000
# rip         Iter        valErr      trErr
# 0           23          0.233333    0.000000
# rip         Iter        valErr      trErr
# 0           24          0.200000    0.000000
# rip         Iter        valErr      trErr
# 0           25          0.213333    0.000000
# rip         Iter        valErr      trErr
# 0           26          0.240000    0.000000
# rip         Iter        valErr      trErr
# 0           27          0.240000    0.000000
# rip         Iter        valErr      trErr
# 0           28          0.246667    0.000000
# rip         Iter        valErr      trErr
# 0           29          0.246667    0.000000
# rip         Iter        valErr      trErr
# 0           30          0.246667    0.000000
# rip         Iter        valErr      trErr
# 1           1           0.066667    0.080000
# rip         Iter        valErr      trErr
# 1           2           0.113333    0.040000
# rip         Iter        valErr      trErr
# 1           3           0.113333    0.040000
# rip         Iter        valErr      trErr
# 1           4           0.133333    0.020000
# rip         Iter        valErr      trErr
# 1           5           0.140000    0.020000
# rip         Iter        valErr      trErr
# 1           6           0.146667    0.020000
# rip         Iter        valErr      trErr
# 1           7           0.146667    0.020000
# rip         Iter        valErr      trErr
# 1           8           0.140000    0.020000
# rip         Iter        valErr      trErr
# 1           9           0.153333    0.020000
# rip         Iter        valErr      trErr
# 1           10          0.160000    0.020000
# rip         Iter        valErr      trErr
# 1           11          0.200000    0.020000
# rip         Iter        valErr      trErr
# 1           12          0.186667    0.020000
# rip         Iter        valErr      trErr
# 1           13          0.193333    0.020000
# rip         Iter        valErr      trErr
# 1           14          0.200000    0.020000
# rip         Iter        valErr      trErr
# 1           15          0.186667    0.020000
# rip         Iter        valErr      trErr
# 1           16          0.186667    0.000000
# rip         Iter        valErr      trErr
# 1           17          0.186667    0.000000
# rip         Iter        valErr      trErr
# 1           18          0.193333    0.000000
# rip         Iter        valErr      trErr
# 1           19          0.193333    0.020000
# rip         Iter        valErr      trErr
# 1           20          0.200000    0.020000
# rip         Iter        valErr      trErr
# 1           21          0.206667    0.020000
# rip         Iter        valErr      trErr
# 1           22          0.193333    0.000000
# rip         Iter        valErr      trErr
# 1           23          0.193333    0.000000
# rip         Iter        valErr      trErr
# 1           24          0.186667    0.000000
# rip         Iter        valErr      trErr
# 1           25          0.200000    0.000000
# rip         Iter        valErr      trErr
# 1           26          0.200000    0.000000
# rip         Iter        valErr      trErr
# 1           27          0.193333    0.000000
# rip         Iter        valErr      trErr
# 1           28          0.200000    0.000000
# rip         Iter        valErr      trErr
# 1           29          0.200000    0.000000
# rip         Iter        valErr      trErr
# 1           30          0.206667    0.000000
# rip         Iter        valErr      trErr
# 2           1           0.080000    0.040000
# rip         Iter        valErr      trErr
# 2           2           0.080000    0.060000
# rip         Iter        valErr      trErr
# 2           3           0.093333    0.000000
# rip         Iter        valErr      trErr
# 2           4           0.113333    0.000000
# rip         Iter        valErr      trErr
# 2           5           0.133333    0.000000
# rip         Iter        valErr      trErr
# 2           6           0.133333    0.000000
# rip         Iter        valErr      trErr
# 2           7           0.153333    0.000000
# rip         Iter        valErr      trErr
# 2           8           0.160000    0.000000
# rip         Iter        valErr      trErr
# 2           9           0.160000    0.020000
# rip         Iter        valErr      trErr
# 2           10          0.153333    0.020000
# rip         Iter        valErr      trErr
# 2           11          0.166667    0.020000
# rip         Iter        valErr      trErr
# 2           12          0.173333    0.020000
# rip         Iter        valErr      trErr
# 2           13          0.173333    0.020000
# rip         Iter        valErr      trErr
# 2           14          0.173333    0.000000
# rip         Iter        valErr      trErr
# 2           15          0.160000    0.000000
# rip         Iter        valErr      trErr
# 2           16          0.166667    0.000000
# rip         Iter        valErr      trErr
# 2           17          0.153333    0.020000
# rip         Iter        valErr      trErr
# 2           18          0.160000    0.020000
# rip         Iter        valErr      trErr
# 2           19          0.160000    0.000000
# rip         Iter        valErr      trErr
# 2           20          0.160000    0.000000
# rip         Iter        valErr      trErr
# 2           21          0.153333    0.000000
# rip         Iter        valErr      trErr
# 2           22          0.153333    0.000000
# rip         Iter        valErr      trErr
# 2           23          0.166667    0.000000
# rip         Iter        valErr      trErr
# 2           24          0.173333    0.000000
# rip         Iter        valErr      trErr
# 2           25          0.166667    0.000000
# rip         Iter        valErr      trErr
# 2           26          0.173333    0.000000
# rip         Iter        valErr      trErr
# 2           27          0.180000    0.000000
# rip         Iter        valErr      trErr
# 2           28          0.160000    0.000000
# rip         Iter        valErr      trErr
# 2           29          0.160000    0.000000
# rip         Iter        valErr      trErr
# 2           30          0.160000    0.000000
# rip         Iter        valErr      trErr
# 3           1           0.080000    0.040000
# rip         Iter        valErr      trErr
# 3           2           0.073333    0.040000
# rip         Iter        valErr      trErr
# 3           3           0.100000    0.020000
# rip         Iter        valErr      trErr
# 3           4           0.080000    0.020000
# rip         Iter        valErr      trErr
# 3           5           0.106667    0.020000
# rip         Iter        valErr      trErr
# 3           6           0.120000    0.000000
# rip         Iter        valErr      trErr
# 3           7           0.133333    0.000000
# rip         Iter        valErr      trErr
# 3           8           0.173333    0.000000
# rip         Iter        valErr      trErr
# 3           9           0.180000    0.000000
# rip         Iter        valErr      trErr
# 3           10          0.180000    0.000000
# rip         Iter        valErr      trErr
# 3           11          0.180000    0.000000
# rip         Iter        valErr      trErr
# 3           12          0.193333    0.000000
# rip         Iter        valErr      trErr
# 3           13          0.193333    0.000000
# rip         Iter        valErr      trErr
# 3           14          0.206667    0.000000
# rip         Iter        valErr      trErr
# 3           15          0.180000    0.000000
# rip         Iter        valErr      trErr
# 3           16          0.180000    0.000000
# rip         Iter        valErr      trErr
# 3           17          0.186667    0.000000
# rip         Iter        valErr      trErr
# 3           18          0.186667    0.000000
# rip         Iter        valErr      trErr
# 3           19          0.166667    0.000000
# rip         Iter        valErr      trErr
# 3           20          0.166667    0.000000
# rip         Iter        valErr      trErr
# 3           21          0.173333    0.000000
# rip         Iter        valErr      trErr
# 3           22          0.146667    0.000000
# rip         Iter        valErr      trErr
# 3           23          0.166667    0.000000
# rip         Iter        valErr      trErr
# 3           24          0.166667    0.000000
# rip         Iter        valErr      trErr
# 3           25          0.173333    0.000000
# rip         Iter        valErr      trErr
# 3           26          0.173333    0.000000
# rip         Iter        valErr      trErr
# 3           27          0.180000    0.000000
# rip         Iter        valErr      trErr
# 3           28          0.180000    0.000000
# rip         Iter        valErr      trErr
# 3           29          0.186667    0.000000
# rip         Iter        valErr      trErr
# 3           30          0.186667    0.000000
# rip         Iter        valErr      trErr
# 4           1           0.073333    0.060000
# rip         Iter        valErr      trErr
# 4           2           0.080000    0.020000
# rip         Iter        valErr      trErr
# 4           3           0.113333    0.000000
# rip         Iter        valErr      trErr
# 4           4           0.100000    0.000000
# rip         Iter        valErr      trErr
# 4           5           0.113333    0.000000
# rip         Iter        valErr      trErr
# 4           6           0.133333    0.000000
# rip         Iter        valErr      trErr
# 4           7           0.126667    0.020000
# rip         Iter        valErr      trErr
# 4           8           0.133333    0.020000
# rip         Iter        valErr      trErr
# 4           9           0.133333    0.000000
# rip         Iter        valErr      trErr
# 4           10          0.133333    0.000000
# rip         Iter        valErr      trErr
# 4           11          0.126667    0.000000
# rip         Iter        valErr      trErr
# 4           12          0.126667    0.000000
# rip         Iter        valErr      trErr
# 4           13          0.113333    0.000000
# rip         Iter        valErr      trErr
# 4           14          0.113333    0.000000
# rip         Iter        valErr      trErr
# 4           15          0.120000    0.000000
# rip         Iter        valErr      trErr
# 4           16          0.113333    0.000000
# rip         Iter        valErr      trErr
# 4           17          0.113333    0.000000
# rip         Iter        valErr      trErr
# 4           18          0.133333    0.000000
# rip         Iter        valErr      trErr
# 4           19          0.133333    0.000000
# rip         Iter        valErr      trErr
# 4           20          0.140000    0.000000
# rip         Iter        valErr      trErr
# 4           21          0.140000    0.000000
# rip         Iter        valErr      trErr
# 4           22          0.140000    0.000000
# rip         Iter        valErr      trErr
# 4           23          0.133333    0.000000
# rip         Iter        valErr      trErr
# 4           24          0.133333    0.000000
# rip         Iter        valErr      trErr
# 4           25          0.146667    0.000000
# rip         Iter        valErr      trErr
# 4           26          0.140000    0.000000
# rip         Iter        valErr      trErr
# 4           27          0.133333    0.000000
# rip         Iter        valErr      trErr
# 4           28          0.153333    0.000000
# rip         Iter        valErr      trErr
# 4           29          0.160000    0.000000
# rip         Iter        valErr      trErr
# 4           30          0.160000    0.000000
# rip         Iter        valErr      trErr
# 5           1           0.066667    0.080000
# rip         Iter        valErr      trErr
# 5           2           0.106667    0.060000
# rip         Iter        valErr      trErr
# 5           3           0.093333    0.060000
# rip         Iter        valErr      trErr
# 5           4           0.113333    0.060000
# rip         Iter        valErr      trErr
# 5           5           0.120000    0.060000
# rip         Iter        valErr      trErr
# 5           6           0.120000    0.060000
# rip         Iter        valErr      trErr
# 5           7           0.113333    0.040000
# rip         Iter        valErr      trErr
# 5           8           0.113333    0.020000
# rip         Iter        valErr      trErr
# 5           9           0.113333    0.020000
# rip         Iter        valErr      trErr
# 5           10          0.126667    0.020000
# rip         Iter        valErr      trErr
# 5           11          0.140000    0.020000
# rip         Iter        valErr      trErr
# 5           12          0.153333    0.000000
# rip         Iter        valErr      trErr
# 5           13          0.153333    0.000000
# rip         Iter        valErr      trErr
# 5           14          0.160000    0.020000
# rip         Iter        valErr      trErr
# 5           15          0.166667    0.020000
# rip         Iter        valErr      trErr
# 5           16          0.160000    0.020000
# rip         Iter        valErr      trErr
# 5           17          0.193333    0.020000
# rip         Iter        valErr      trErr
# 5           18          0.193333    0.020000
# rip         Iter        valErr      trErr
# 5           19          0.193333    0.020000
# rip         Iter        valErr      trErr
# 5           20          0.206667    0.000000
# rip         Iter        valErr      trErr
# 5           21          0.200000    0.000000
# rip         Iter        valErr      trErr
# 5           22          0.206667    0.000000
# rip         Iter        valErr      trErr
# 5           23          0.200000    0.000000
# rip         Iter        valErr      trErr
# 5           24          0.200000    0.000000
# rip         Iter        valErr      trErr
# 5           25          0.206667    0.000000
# rip         Iter        valErr      trErr
# 5           26          0.220000    0.000000
# rip         Iter        valErr      trErr
# 5           27          0.220000    0.000000
# rip         Iter        valErr      trErr
# 5           28          0.220000    0.000000
# rip         Iter        valErr      trErr
# 5           29          0.220000    0.000000
# rip         Iter        valErr      trErr
# 5           30          0.220000    0.000000
# rip         Iter        valErr      trErr
# 6           1           0.060000    0.100000
# rip         Iter        valErr      trErr
# 6           2           0.066667    0.100000
# rip         Iter        valErr      trErr
# 6           3           0.066667    0.080000
# rip         Iter        valErr      trErr
# 6           4           0.073333    0.100000
# rip         Iter        valErr      trErr
# 6           5           0.120000    0.060000
# rip         Iter        valErr      trErr
# 6           6           0.113333    0.080000
# rip         Iter        valErr      trErr
# 6           7           0.120000    0.060000
# rip         Iter        valErr      trErr
# 6           8           0.120000    0.040000
# rip         Iter        valErr      trErr
# 6           9           0.133333    0.040000
# rip         Iter        valErr      trErr
# 6           10          0.153333    0.020000
# rip         Iter        valErr      trErr
# 6           11          0.140000    0.020000
# rip         Iter        valErr      trErr
# 6           12          0.166667    0.020000
# rip         Iter        valErr      trErr
# 6           13          0.173333    0.020000
# rip         Iter        valErr      trErr
# 6           14          0.166667    0.000000
# rip         Iter        valErr      trErr
# 6           15          0.200000    0.020000
# rip         Iter        valErr      trErr
# 6           16          0.173333    0.020000
# rip         Iter        valErr      trErr
# 6           17          0.206667    0.020000
# rip         Iter        valErr      trErr
# 6           18          0.213333    0.020000
# rip         Iter        valErr      trErr
# 6           19          0.213333    0.020000
# rip         Iter        valErr      trErr
# 6           20          0.220000    0.020000
# rip         Iter        valErr      trErr
# 6           21          0.193333    0.020000
# rip         Iter        valErr      trErr
# 6           22          0.213333    0.000000
# rip         Iter        valErr      trErr
# 6           23          0.200000    0.000000
# rip         Iter        valErr      trErr
# 6           24          0.200000    0.000000
# rip         Iter        valErr      trErr
# 6           25          0.193333    0.000000
# rip         Iter        valErr      trErr
# 6           26          0.213333    0.000000
# rip         Iter        valErr      trErr
# 6           27          0.206667    0.000000
# rip         Iter        valErr      trErr
# 6           28          0.206667    0.000000
# rip         Iter        valErr      trErr
# 6           29          0.206667    0.000000
# rip         Iter        valErr      trErr
# 6           30          0.200000    0.000000
# rip         Iter        valErr      trErr
# 7           1           0.060000    0.100000
# rip         Iter        valErr      trErr
# 7           2           0.093333    0.060000
# rip         Iter        valErr      trErr
# 7           3           0.120000    0.060000
# rip         Iter        valErr      trErr
# 7           4           0.126667    0.040000
# rip         Iter        valErr      trErr
# 7           5           0.133333    0.060000
# rip         Iter        valErr      trErr
# 7           6           0.153333    0.040000
# rip         Iter        valErr      trErr
# 7           7           0.133333    0.060000
# rip         Iter        valErr      trErr
# 7           8           0.146667    0.020000
# rip         Iter        valErr      trErr
# 7           9           0.153333    0.020000
# rip         Iter        valErr      trErr
# 7           10          0.133333    0.000000
# rip         Iter        valErr      trErr
# 7           11          0.140000    0.000000
# rip         Iter        valErr      trErr
# 7           12          0.160000    0.000000
# rip         Iter        valErr      trErr
# 7           13          0.160000    0.000000
# rip         Iter        valErr      trErr
# 7           14          0.173333    0.000000
# rip         Iter        valErr      trErr
# 7           15          0.180000    0.000000
# rip         Iter        valErr      trErr
# 7           16          0.173333    0.000000
# rip         Iter        valErr      trErr
# 7           17          0.166667    0.000000
# rip         Iter        valErr      trErr
# 7           18          0.166667    0.000000
# rip         Iter        valErr      trErr
# 7           19          0.160000    0.000000
# rip         Iter        valErr      trErr
# 7           20          0.173333    0.000000
# rip         Iter        valErr      trErr
# 7           21          0.186667    0.000000
# rip         Iter        valErr      trErr
# 7           22          0.186667    0.000000
# rip         Iter        valErr      trErr
# 7           23          0.186667    0.000000
# rip         Iter        valErr      trErr
# 7           24          0.186667    0.000000
# rip         Iter        valErr      trErr
# 7           25          0.180000    0.000000
# rip         Iter        valErr      trErr
# 7           26          0.173333    0.000000
# rip         Iter        valErr      trErr
# 7           27          0.180000    0.000000
# rip         Iter        valErr      trErr
# 7           28          0.180000    0.000000
# rip         Iter        valErr      trErr
# 7           29          0.173333    0.000000
# rip         Iter        valErr      trErr
# 7           30          0.173333    0.000000
# rip         Iter        valErr      trErr
# 8           1           0.086667    0.020000
# rip         Iter        valErr      trErr
# 8           2           0.086667    0.000000
# rip         Iter        valErr      trErr
# 8           3           0.106667    0.000000
# rip         Iter        valErr      trErr
# 8           4           0.113333    0.020000
# rip         Iter        valErr      trErr
# 8           5           0.113333    0.020000
# rip         Iter        valErr      trErr
# 8           6           0.113333    0.020000
# rip         Iter        valErr      trErr
# 8           7           0.113333    0.020000
# rip         Iter        valErr      trErr
# 8           8           0.126667    0.000000
# rip         Iter        valErr      trErr
# 8           9           0.126667    0.000000
# rip         Iter        valErr      trErr
# 8           10          0.133333    0.000000
# rip         Iter        valErr      trErr
# 8           11          0.133333    0.000000
# rip         Iter        valErr      trErr
# 8           12          0.133333    0.000000
# rip         Iter        valErr      trErr
# 8           13          0.126667    0.000000
# rip         Iter        valErr      trErr
# 8           14          0.126667    0.000000
# rip         Iter        valErr      trErr
# 8           15          0.153333    0.000000
# rip         Iter        valErr      trErr
# 8           16          0.133333    0.000000
# rip         Iter        valErr      trErr
# 8           17          0.153333    0.000000
# rip         Iter        valErr      trErr
# 8           18          0.153333    0.000000
# rip         Iter        valErr      trErr
# 8           19          0.146667    0.000000
# rip         Iter        valErr      trErr
# 8           20          0.166667    0.000000
# rip         Iter        valErr      trErr
# 8           21          0.160000    0.000000
# rip         Iter        valErr      trErr
# 8           22          0.173333    0.000000
# rip         Iter        valErr      trErr
# 8           23          0.166667    0.000000
# rip         Iter        valErr      trErr
# 8           24          0.180000    0.000000
# rip         Iter        valErr      trErr
# 8           25          0.166667    0.000000
# rip         Iter        valErr      trErr
# 8           26          0.173333    0.000000
# rip         Iter        valErr      trErr
# 8           27          0.173333    0.000000
# rip         Iter        valErr      trErr
# 8           28          0.180000    0.000000
# rip         Iter        valErr      trErr
# 8           29          0.180000    0.000000
# rip         Iter        valErr      trErr
# 8           30          0.180000    0.000000
# rip         Iter        valErr      trErr
# 9           1           0.080000    0.040000
# rip         Iter        valErr      trErr
# 9           2           0.086667    0.060000
# rip         Iter        valErr      trErr
# 9           3           0.113333    0.040000
# rip         Iter        valErr      trErr
# 9           4           0.093333    0.000000
# rip         Iter        valErr      trErr
# 9           5           0.093333    0.000000
# rip         Iter        valErr      trErr
# 9           6           0.086667    0.020000
# rip         Iter        valErr      trErr
# 9           7           0.106667    0.040000
# rip         Iter        valErr      trErr
# 9           8           0.120000    0.040000
# rip         Iter        valErr      trErr
# 9           9           0.126667    0.020000
# rip         Iter        valErr      trErr
# 9           10          0.140000    0.020000
# rip         Iter        valErr      trErr
# 9           11          0.153333    0.020000
# rip         Iter        valErr      trErr
# 9           12          0.173333    0.020000
# rip         Iter        valErr      trErr
# 9           13          0.166667    0.000000
# rip         Iter        valErr      trErr
# 9           14          0.166667    0.000000
# rip         Iter        valErr      trErr
# 9           15          0.173333    0.000000
# rip         Iter        valErr      trErr
# 9           16          0.180000    0.000000
# rip         Iter        valErr      trErr
# 9           17          0.200000    0.000000
# rip         Iter        valErr      trErr
# 9           18          0.173333    0.000000
# rip         Iter        valErr      trErr
# 9           19          0.206667    0.000000
# rip         Iter        valErr      trErr
# 9           20          0.206667    0.000000
# rip         Iter        valErr      trErr
# 9           21          0.200000    0.000000
# rip         Iter        valErr      trErr
# 9           22          0.226667    0.000000
# rip         Iter        valErr      trErr
# 9           23          0.226667    0.000000
# rip         Iter        valErr      trErr
# 9           24          0.233333    0.000000
# rip         Iter        valErr      trErr
# 9           25          0.233333    0.000000
# rip         Iter        valErr      trErr
# 9           26          0.226667    0.000000
# rip         Iter        valErr      trErr
# 9           27          0.233333    0.000000
# rip         Iter        valErr      trErr
# 9           28          0.233333    0.000000
# rip         Iter        valErr      trErr
# 9           29          0.233333    0.000000
# rip         Iter        valErr      trErr
# 9           30          0.233333    0.000000
# rip         Iter        valErr      trErr
# 10          1           0.080000    0.040000
# rip         Iter        valErr      trErr
# 10          2           0.080000    0.020000
# rip         Iter        valErr      trErr
# 10          3           0.086667    0.020000
# rip         Iter        valErr      trErr
# 10          4           0.080000    0.020000
# rip         Iter        valErr      trErr
# 10          5           0.080000    0.020000
# rip         Iter        valErr      trErr
# 10          6           0.066667    0.040000
# rip         Iter        valErr      trErr
# 10          7           0.073333    0.040000
# rip         Iter        valErr      trErr
# 10          8           0.100000    0.040000
# rip         Iter        valErr      trErr
# 10          9           0.120000    0.040000
# rip         Iter        valErr      trErr
# 10          10          0.100000    0.040000
# rip         Iter        valErr      trErr
# 10          11          0.093333    0.040000
# rip         Iter        valErr      trErr
# 10          12          0.093333    0.040000
# rip         Iter        valErr      trErr
# 10          13          0.086667    0.020000
# rip         Iter        valErr      trErr
# 10          14          0.093333    0.020000
# rip         Iter        valErr      trErr
# 10          15          0.100000    0.020000
# rip         Iter        valErr      trErr
# 10          16          0.100000    0.020000
# rip         Iter        valErr      trErr
# 10          17          0.106667    0.020000
# rip         Iter        valErr      trErr
# 10          18          0.113333    0.020000
# rip         Iter        valErr      trErr
# 10          19          0.113333    0.020000
# rip         Iter        valErr      trErr
# 10          20          0.113333    0.020000
# rip         Iter        valErr      trErr
# 10          21          0.113333    0.020000
# rip         Iter        valErr      trErr
# 10          22          0.126667    0.020000
# rip         Iter        valErr      trErr
# 10          23          0.126667    0.020000
# rip         Iter        valErr      trErr
# 10          24          0.133333    0.020000
# rip         Iter        valErr      trErr
# 10          25          0.133333    0.020000
# rip         Iter        valErr      trErr
# 10          26          0.140000    0.020000
# rip         Iter        valErr      trErr
# 10          27          0.140000    0.020000
# rip         Iter        valErr      trErr
# 10          28          0.153333    0.020000
# rip         Iter        valErr      trErr
# 10          29          0.146667    0.020000
# rip         Iter        valErr      trErr
# 10          30          0.146667    0.020000
# rip         Iter        valErr      trErr
# 11          1           0.073333    0.060000
# rip         Iter        valErr      trErr
# 11          2           0.086667    0.040000
# rip         Iter        valErr      trErr
# 11          3           0.100000    0.040000
# rip         Iter        valErr      trErr
# 11          4           0.120000    0.040000
# rip         Iter        valErr      trErr
# 11          5           0.126667    0.040000
# rip         Iter        valErr      trErr
# 11          6           0.133333    0.020000
# rip         Iter        valErr      trErr
# 11          7           0.146667    0.020000
# rip         Iter        valErr      trErr
# 11          8           0.153333    0.020000
# rip         Iter        valErr      trErr
# 11          9           0.153333    0.020000
# rip         Iter        valErr      trErr
# 11          10          0.160000    0.040000
# rip         Iter        valErr      trErr
# 11          11          0.180000    0.020000
# rip         Iter        valErr      trErr
# 11          12          0.173333    0.000000
# rip         Iter        valErr      trErr
# 11          13          0.193333    0.000000
# rip         Iter        valErr      trErr
# 11          14          0.180000    0.000000
# rip         Iter        valErr      trErr
# 11          15          0.193333    0.000000
# rip         Iter        valErr      trErr
# 11          16          0.200000    0.000000
# rip         Iter        valErr      trErr
# 11          17          0.200000    0.000000
# rip         Iter        valErr      trErr
# 11          18          0.186667    0.000000
# rip         Iter        valErr      trErr
# 11          19          0.180000    0.000000
# rip         Iter        valErr      trErr
# 11          20          0.166667    0.000000
# rip         Iter        valErr      trErr
# 11          21          0.166667    0.000000
# rip         Iter        valErr      trErr
# 11          22          0.166667    0.000000
# rip         Iter        valErr      trErr
# 11          23          0.160000    0.000000
# rip         Iter        valErr      trErr
# 11          24          0.146667    0.000000
# rip         Iter        valErr      trErr
# 11          25          0.160000    0.000000
# rip         Iter        valErr      trErr
# 11          26          0.160000    0.000000
# rip         Iter        valErr      trErr
# 11          27          0.160000    0.000000
# rip         Iter        valErr      trErr
# 11          28          0.180000    0.000000
# rip         Iter        valErr      trErr
# 11          29          0.173333    0.000000
# rip         Iter        valErr      trErr
# 11          30          0.173333    0.000000
# rip         Iter        valErr      trErr
# 12          1           0.080000    0.040000
# rip         Iter        valErr      trErr
# 12          2           0.113333    0.080000
# rip         Iter        valErr      trErr
# 12          3           0.120000    0.040000
# rip         Iter        valErr      trErr
# 12          4           0.100000    0.020000
# rip         Iter        valErr      trErr
# 12          5           0.113333    0.020000
# rip         Iter        valErr      trErr
# 12          6           0.113333    0.020000
# rip         Iter        valErr      trErr
# 12          7           0.113333    0.040000
# rip         Iter        valErr      trErr
# 12          8           0.113333    0.000000
# rip         Iter        valErr      trErr
# 12          9           0.146667    0.000000
# rip         Iter        valErr      trErr
# 12          10          0.120000    0.000000
# rip         Iter        valErr      trErr
# 12          11          0.133333    0.000000
# rip         Iter        valErr      trErr
# 12          12          0.120000    0.000000
# rip         Iter        valErr      trErr
# 12          13          0.126667    0.000000
# rip         Iter        valErr      trErr
# 12          14          0.126667    0.000000
# rip         Iter        valErr      trErr
# 12          15          0.133333    0.000000
# rip         Iter        valErr      trErr
# 12          16          0.140000    0.000000
# rip         Iter        valErr      trErr
# 12          17          0.133333    0.000000
# rip         Iter        valErr      trErr
# 12          18          0.133333    0.000000
# rip         Iter        valErr      trErr
# 12          19          0.133333    0.000000
# rip         Iter        valErr      trErr
# 12          20          0.133333    0.000000
# rip         Iter        valErr      trErr
# 12          21          0.126667    0.000000
# rip         Iter        valErr      trErr
# 12          22          0.126667    0.000000
# rip         Iter        valErr      trErr
# 12          23          0.133333    0.000000
# rip         Iter        valErr      trErr
# 12          24          0.133333    0.000000
# rip         Iter        valErr      trErr
# 12          25          0.146667    0.000000
# rip         Iter        valErr      trErr
# 12          26          0.153333    0.000000
# rip         Iter        valErr      trErr
# 12          27          0.153333    0.000000
# rip         Iter        valErr      trErr
# 12          28          0.146667    0.000000
# rip         Iter        valErr      trErr
# 12          29          0.146667    0.000000
# rip         Iter        valErr      trErr
# 12          30          0.140000    0.000000
# rip         Iter        valErr      trErr
# 13          1           0.060000    0.100000
# rip         Iter        valErr      trErr
# 13          2           0.080000    0.100000
# rip         Iter        valErr      trErr
# 13          3           0.073333    0.080000
# rip         Iter        valErr      trErr
# 13          4           0.086667    0.060000
# rip         Iter        valErr      trErr
# 13          5           0.093333    0.060000
# rip         Iter        valErr      trErr
# 13          6           0.100000    0.040000
# rip         Iter        valErr      trErr
# 13          7           0.100000    0.040000
# rip         Iter        valErr      trErr
# 13          8           0.093333    0.040000
# rip         Iter        valErr      trErr
# 13          9           0.086667    0.040000
# rip         Iter        valErr      trErr
# 13          10          0.093333    0.040000
# rip         Iter        valErr      trErr
# 13          11          0.100000    0.040000
# rip         Iter        valErr      trErr
# 13          12          0.100000    0.040000
# rip         Iter        valErr      trErr
# 13          13          0.093333    0.020000
# rip         Iter        valErr      trErr
# 13          14          0.106667    0.040000
# rip         Iter        valErr      trErr
# 13          15          0.106667    0.040000
# rip         Iter        valErr      trErr
# 13          16          0.120000    0.040000
# rip         Iter        valErr      trErr
# 13          17          0.133333    0.040000
# rip         Iter        valErr      trErr
# 13          18          0.146667    0.040000
# rip         Iter        valErr      trErr
# 13          19          0.146667    0.040000
# rip         Iter        valErr      trErr
# 13          20          0.153333    0.040000
# rip         Iter        valErr      trErr
# 13          21          0.166667    0.040000
# rip         Iter        valErr      trErr
# 13          22          0.173333    0.040000
# rip         Iter        valErr      trErr
# 13          23          0.186667    0.040000
# rip         Iter        valErr      trErr
# 13          24          0.173333    0.040000
# rip         Iter        valErr      trErr
# 13          25          0.173333    0.040000
# rip         Iter        valErr      trErr
# 13          26          0.160000    0.040000
# rip         Iter        valErr      trErr
# 13          27          0.166667    0.040000
# rip         Iter        valErr      trErr
# 13          28          0.166667    0.040000
# rip         Iter        valErr      trErr
# 13          29          0.166667    0.040000
# rip         Iter        valErr      trErr
# 13          30          0.173333    0.040000
# rip         Iter        valErr      trErr
# 14          1           0.073333    0.060000
# rip         Iter        valErr      trErr
# 14          2           0.066667    0.040000
# rip         Iter        valErr      trErr
# 14          3           0.086667    0.040000
# rip         Iter        valErr      trErr
# 14          4           0.093333    0.020000
# rip         Iter        valErr      trErr
# 14          5           0.106667    0.020000
# rip         Iter        valErr      trErr
# 14          6           0.120000    0.000000
# rip         Iter        valErr      trErr
# 14          7           0.140000    0.000000
# rip         Iter        valErr      trErr
# 14          8           0.140000    0.000000
# rip         Iter        valErr      trErr
# 14          9           0.153333    0.000000
# rip         Iter        valErr      trErr
# 14          10          0.186667    0.000000
# rip         Iter        valErr      trErr
# 14          11          0.186667    0.000000
# rip         Iter        valErr      trErr
# 14          12          0.193333    0.000000
# rip         Iter        valErr      trErr
# 14          13          0.206667    0.000000
# rip         Iter        valErr      trErr
# 14          14          0.233333    0.000000
# rip         Iter        valErr      trErr
# 14          15          0.220000    0.000000
# rip         Iter        valErr      trErr
# 14          16          0.220000    0.000000
# rip         Iter        valErr      trErr
# 14          17          0.220000    0.000000
# rip         Iter        valErr      trErr
# 14          18          0.220000    0.000000
# rip         Iter        valErr      trErr
# 14          19          0.220000    0.000000
# rip         Iter        valErr      trErr
# 14          20          0.233333    0.000000
# rip         Iter        valErr      trErr
# 14          21          0.253333    0.000000
# rip         Iter        valErr      trErr
# 14          22          0.260000    0.000000
# rip         Iter        valErr      trErr
# 14          23          0.260000    0.000000
# rip         Iter        valErr      trErr
# 14          24          0.260000    0.000000
# rip         Iter        valErr      trErr
# 14          25          0.253333    0.000000
# rip         Iter        valErr      trErr
# 14          26          0.246667    0.000000
# rip         Iter        valErr      trErr
# 14          27          0.246667    0.000000
# rip         Iter        valErr      trErr
# 14          28          0.246667    0.000000
# rip         Iter        valErr      trErr
# 14          29          0.246667    0.000000
# rip         Iter        valErr      trErr
# 14          30          0.246667    0.000000
# rip         Iter        valErr      trErr
# 15          1           0.073333    0.060000
# rip         Iter        valErr      trErr
# 15          2           0.100000    0.020000
# rip         Iter        valErr      trErr
# 15          3           0.126667    0.000000
# rip         Iter        valErr      trErr
# 15          4           0.140000    0.000000
# rip         Iter        valErr      trErr
# 15          5           0.160000    0.000000
# rip         Iter        valErr      trErr
# 15          6           0.146667    0.000000
# rip         Iter        valErr      trErr
# 15          7           0.140000    0.000000
# rip         Iter        valErr      trErr
# 15          8           0.113333    0.000000
# rip         Iter        valErr      trErr
# 15          9           0.126667    0.000000
# rip         Iter        valErr      trErr
# 15          10          0.153333    0.000000
# rip         Iter        valErr      trErr
# 15          11          0.146667    0.000000
# rip         Iter        valErr      trErr
# 15          12          0.146667    0.000000
# rip         Iter        valErr      trErr
# 15          13          0.126667    0.000000
# rip         Iter        valErr      trErr
# 15          14          0.166667    0.000000
# rip         Iter        valErr      trErr
# 15          15          0.153333    0.000000
# rip         Iter        valErr      trErr
# 15          16          0.173333    0.000000
# rip         Iter        valErr      trErr
# 15          17          0.160000    0.000000
# rip         Iter        valErr      trErr
# 15          18          0.160000    0.000000
# rip         Iter        valErr      trErr
# 15          19          0.140000    0.000000
# rip         Iter        valErr      trErr
# 15          20          0.160000    0.000000
# rip         Iter        valErr      trErr
# 15          21          0.160000    0.000000
# rip         Iter        valErr      trErr
# 15          22          0.153333    0.000000
# rip         Iter        valErr      trErr
# 15          23          0.153333    0.000000
# rip         Iter        valErr      trErr
# 15          24          0.160000    0.000000
# rip         Iter        valErr      trErr
# 15          25          0.160000    0.000000
# rip         Iter        valErr      trErr
# 15          26          0.160000    0.000000
# rip         Iter        valErr      trErr
# 15          27          0.166667    0.000000
# rip         Iter        valErr      trErr
# 15          28          0.160000    0.000000
# rip         Iter        valErr      trErr
# 15          29          0.160000    0.000000
# rip         Iter        valErr      trErr
# 15          30          0.160000    0.000000
# rip         Iter        valErr      trErr
# 16          1           0.086667    0.020000
# rip         Iter        valErr      trErr
# 16          2           0.100000    0.000000
# rip         Iter        valErr      trErr
# 16          3           0.120000    0.000000
# rip         Iter        valErr      trErr
# 16          4           0.126667    0.000000
# rip         Iter        valErr      trErr
# 16          5           0.153333    0.000000
# rip         Iter        valErr      trErr
# 16          6           0.166667    0.000000
# rip         Iter        valErr      trErr
# 16          7           0.166667    0.020000
# rip         Iter        valErr      trErr
# 16          8           0.173333    0.000000
# rip         Iter        valErr      trErr
# 16          9           0.166667    0.000000
# rip         Iter        valErr      trErr
# 16          10          0.180000    0.000000
# rip         Iter        valErr      trErr
# 16          11          0.186667    0.000000
# rip         Iter        valErr      trErr
# 16          12          0.173333    0.000000
# rip         Iter        valErr      trErr
# 16          13          0.180000    0.000000
# rip         Iter        valErr      trErr
# 16          14          0.186667    0.000000
# rip         Iter        valErr      trErr
# 16          15          0.193333    0.000000
# rip         Iter        valErr      trErr
# 16          16          0.186667    0.000000
# rip         Iter        valErr      trErr
# 16          17          0.186667    0.000000
# rip         Iter        valErr      trErr
# 16          18          0.186667    0.000000
# rip         Iter        valErr      trErr
# 16          19          0.186667    0.000000
# rip         Iter        valErr      trErr
# 16          20          0.193333    0.000000
# rip         Iter        valErr      trErr
# 16          21          0.193333    0.000000
# rip         Iter        valErr      trErr
# 16          22          0.186667    0.000000
# rip         Iter        valErr      trErr
# 16          23          0.200000    0.000000
# rip         Iter        valErr      trErr
# 16          24          0.193333    0.000000
# rip         Iter        valErr      trErr
# 16          25          0.193333    0.000000
# rip         Iter        valErr      trErr
# 16          26          0.193333    0.000000
# rip         Iter        valErr      trErr
# 16          27          0.200000    0.000000
# rip         Iter        valErr      trErr
# 16          28          0.200000    0.000000
# rip         Iter        valErr      trErr
# 16          29          0.200000    0.000000
# rip         Iter        valErr      trErr
# 16          30          0.200000    0.000000
# rip         Iter        valErr      trErr
# 17          1           0.073333    0.060000
# rip         Iter        valErr      trErr
# 17          2           0.086667    0.040000
# rip         Iter        valErr      trErr
# 17          3           0.120000    0.060000
# rip         Iter        valErr      trErr
# 17          4           0.140000    0.040000
# rip         Iter        valErr      trErr
# 17          5           0.173333    0.020000
# rip         Iter        valErr      trErr
# 17          6           0.180000    0.000000
# rip         Iter        valErr      trErr
# 17          7           0.166667    0.000000
# rip         Iter        valErr      trErr
# 17          8           0.200000    0.000000
# rip         Iter        valErr      trErr
# 17          9           0.213333    0.000000
# rip         Iter        valErr      trErr
# 17          10          0.206667    0.000000
# rip         Iter        valErr      trErr
# 17          11          0.220000    0.000000
# rip         Iter        valErr      trErr
# 17          12          0.226667    0.000000
# rip         Iter        valErr      trErr
# 17          13          0.233333    0.000000
# rip         Iter        valErr      trErr
# 17          14          0.220000    0.000000
# rip         Iter        valErr      trErr
# 17          15          0.226667    0.000000
# rip         Iter        valErr      trErr
# 17          16          0.206667    0.000000
# rip         Iter        valErr      trErr
# 17          17          0.233333    0.000000
# rip         Iter        valErr      trErr
# 17          18          0.233333    0.000000
# rip         Iter        valErr      trErr
# 17          19          0.220000    0.000000
# rip         Iter        valErr      trErr
# 17          20          0.220000    0.000000
# rip         Iter        valErr      trErr
# 17          21          0.226667    0.000000
# rip         Iter        valErr      trErr
# 17          22          0.220000    0.000000
# rip         Iter        valErr      trErr
# 17          23          0.226667    0.000000
# rip         Iter        valErr      trErr
# 17          24          0.206667    0.000000
# rip         Iter        valErr      trErr
# 17          25          0.206667    0.000000
# rip         Iter        valErr      trErr
# 17          26          0.206667    0.000000
# rip         Iter        valErr      trErr
# 17          27          0.220000    0.000000
# rip         Iter        valErr      trErr
# 17          28          0.226667    0.000000
# rip         Iter        valErr      trErr
# 17          29          0.233333    0.000000
# rip         Iter        valErr      trErr
# 17          30          0.240000    0.000000
# rip         Iter        valErr      trErr
# 18          1           0.073333    0.060000
# rip         Iter        valErr      trErr
# 18          2           0.080000    0.020000
# rip         Iter        valErr      trErr
# 18          3           0.086667    0.020000
# rip         Iter        valErr      trErr
# 18          4           0.093333    0.000000
# rip         Iter        valErr      trErr
# 18          5           0.093333    0.000000
# rip         Iter        valErr      trErr
# 18          6           0.073333    0.000000
# rip         Iter        valErr      trErr
# 18          7           0.093333    0.000000
# rip         Iter        valErr      trErr
# 18          8           0.113333    0.000000
# rip         Iter        valErr      trErr
# 18          9           0.100000    0.000000
# rip         Iter        valErr      trErr
# 18          10          0.106667    0.000000
# rip         Iter        valErr      trErr
# 18          11          0.106667    0.000000
# rip         Iter        valErr      trErr
# 18          12          0.160000    0.000000
# rip         Iter        valErr      trErr
# 18          13          0.133333    0.000000
# rip         Iter        valErr      trErr
# 18          14          0.140000    0.000000
# rip         Iter        valErr      trErr
# 18          15          0.146667    0.000000
# rip         Iter        valErr      trErr
# 18          16          0.153333    0.000000
# rip         Iter        valErr      trErr
# 18          17          0.153333    0.000000
# rip         Iter        valErr      trErr
# 18          18          0.133333    0.000000
# rip         Iter        valErr      trErr
# 18          19          0.146667    0.000000
# rip         Iter        valErr      trErr
# 18          20          0.153333    0.000000
# rip         Iter        valErr      trErr
# 18          21          0.146667    0.000000
# rip         Iter        valErr      trErr
# 18          22          0.140000    0.000000
# rip         Iter        valErr      trErr
# 18          23          0.146667    0.000000
# rip         Iter        valErr      trErr
# 18          24          0.133333    0.000000
# rip         Iter        valErr      trErr
# 18          25          0.120000    0.000000
# rip         Iter        valErr      trErr
# 18          26          0.140000    0.000000
# rip         Iter        valErr      trErr
# 18          27          0.133333    0.000000
# rip         Iter        valErr      trErr
# 18          28          0.126667    0.000000
# rip         Iter        valErr      trErr
# 18          29          0.133333    0.000000
# rip         Iter        valErr      trErr
# 18          30          0.133333    0.000000
# rip         Iter        valErr      trErr
# 19          1           0.066667    0.080000
# rip         Iter        valErr      trErr
# 19          2           0.086667    0.080000
# rip         Iter        valErr      trErr
# 19          3           0.093333    0.040000
# rip         Iter        valErr      trErr
# 19          4           0.106667    0.060000
# rip         Iter        valErr      trErr
# 19          5           0.120000    0.040000
# rip         Iter        valErr      trErr
# 19          6           0.140000    0.040000
# rip         Iter        valErr      trErr
# 19          7           0.126667    0.040000
# rip         Iter        valErr      trErr
# 19          8           0.140000    0.000000
# rip         Iter        valErr      trErr
# 19          9           0.146667    0.000000
# rip         Iter        valErr      trErr
# 19          10          0.160000    0.020000
# rip         Iter        valErr      trErr
# 19          11          0.153333    0.020000
# rip         Iter        valErr      trErr
# 19          12          0.180000    0.000000
# rip         Iter        valErr      trErr
# 19          13          0.193333    0.000000
# rip         Iter        valErr      trErr
# 19          14          0.193333    0.020000
# rip         Iter        valErr      trErr
# 19          15          0.200000    0.000000
# rip         Iter        valErr      trErr
# 19          16          0.186667    0.020000
# rip         Iter        valErr      trErr
# 19          17          0.193333    0.000000
# rip         Iter        valErr      trErr
# 19          18          0.186667    0.000000
# rip         Iter        valErr      trErr
# 19          19          0.166667    0.020000
# rip         Iter        valErr      trErr
# 19          20          0.166667    0.000000
# rip         Iter        valErr      trErr
# 19          21          0.166667    0.000000
# rip         Iter        valErr      trErr
# 19          22          0.160000    0.020000
# rip         Iter        valErr      trErr
# 19          23          0.160000    0.020000
# rip         Iter        valErr      trErr
# 19          24          0.166667    0.020000
# rip         Iter        valErr      trErr
# 19          25          0.166667    0.020000
# rip         Iter        valErr      trErr
# 19          26          0.180000    0.020000
# rip         Iter        valErr      trErr
# 19          27          0.180000    0.020000
# rip         Iter        valErr      trErr
# 19          28          0.180000    0.020000
# rip         Iter        valErr      trErr
# 19          29          0.173333    0.020000
# rip         Iter        valErr      trErr
# 19          30          0.166667    0.020000

# %%
a.shape
# Out:
# (5, 5)
